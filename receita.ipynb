# %% [markdown]
# Top 10 clubes(times) com Mais Receitas 2024

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
clubes = ["Real Madrid",
"Manchester City", 
"PSG", 
"Barcelona",
"Manchester United",
"Bayern Munique", 
"Liverpool",
"Tottenham",
"Chelsea",
"Arsenal" ]

# %%
receitaseurom = [
    831.4,
    825.9,
    801.8,
    800.1,
    745.8,
    744.0,
    682.9,
    631.5,
    589.4,
    532.6
]

# %%
receitas = pd.Series(receitaseurom, clubes)
receitas
# Out:
# Real Madrid          831.4
# Manchester City      825.9
# PSG                  801.8
# Barcelona            800.1
# Manchester United    745.8
# Bayern Munique       744.0
# Liverpool            682.9
# Tottenham            631.5
# Chelsea              589.4
# Arsenal              532.6
# dtype: float64

# %% [markdown]
# Vizualização da Tabela

# %%
receitas.plot()
# Out:
# <Axes: >

# %% [markdown]
# De acordo com a gráfico podemos vizualizar as maiores receitas dos clubes em milhões de Euros, podemos peceber como existe uma grande diferença do time com maior receita(Real Madrid) para os ultimos colocados do TOP 10 como o time do chelsea.
